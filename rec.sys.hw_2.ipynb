# %%
import pandas as pd
import numpy as np

from tqdm import tqdm_notebook

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

# %%
links = pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
def change_string(s):
    return ' '.join(s.replace(' ', '').replace('-', '').split('|'))

def change_string1(s):
    return ' '.join(s.split(' '))

# %%
movie_genres = [change_string(g) for g in movies.genres.values]

# %%
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(movie_genres)
tfidf_vectorizer.vocabulary_
# Out:
# {'adventure': 1,
#  'animation': 2,
#  'children': 3,
#  'comedy': 4,
#  'fantasy': 8,
#  'romance': 15,
#  'drama': 7,
#  'action': 0,
#  'crime': 5,
#  'thriller': 17,
#  'horror': 10,
#  'mystery': 13,
#  'scifi': 16,
#  'war': 18,
#  'musical': 12,
#  'documentary': 6,
#  'imax': 11,
#  'western': 19,
#  'filmnoir': 9,
#  'nogenreslisted': 14}

# %%
neigh = NearestNeighbors(n_neighbors=7, n_jobs=-1, metric='euclidean') 
neigh.fit(X_train_tfidf)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='euclidean',
#                  metric_params=None, n_jobs=-1, n_neighbors=7, p=2, radius=1.0)

# %%
test = change_string("Adventure|Comedy|Fantasy|Crime")
X_tfidf2 = tfidf_vectorizer.transform([test])
res = neigh.kneighbors(X_tfidf2, return_distance=True)
res[1][0]
# Out:
# array([6774, 9096, 5636, 6723, 3376, 7496, 9717], dtype=int64)

# %%
movies.iloc[res[1][0]]
# Out:
#       movieId                                              title  \
# 6774    60074                                     Hancock (2008)
# 9096   143559                                L.A. Slasher (2015)
# 5636    27368  Asterix & Obelix: Mission Cleopatra (Astérix &...
# 6723    58972                                Nim's Island (2008)
# 3376     4591                             Erik the Viking (1989)
# 7496    82854                          Gulliver's Travels (2010)
# 9717   188833              The Man Who Killed Don Quixote (2018)
#
#                                      genres
# 6774  Action|Adventure|Comedy|Crime|Fantasy
# 9096                   Comedy|Crime|Fantasy
# 5636               Adventure|Comedy|Fantasy
# 6723               Adventure|Comedy|Fantasy
# 3376               Adventure|Comedy|Fantasy
# 7496               Adventure|Comedy|Fantasy
# 9717               Adventure|Comedy|Fantasy

# %%
movies_and_tags = movies.join(tags.set_index('movieId'), on='movieId')
movies_and_tags.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#    userId               tag     timestamp
# 0   336.0             pixar  1.139046e+09
# 0   474.0             pixar  1.137207e+09
# 0   567.0               fun  1.525286e+09
# 1    62.0           fantasy  1.528844e+09
# 1    62.0  magic board game  1.528844e+09

# %%
movie_tags = movies_and_tags.tag.values
movie_tags
# Out:
# array(['pixar', 'pixar', 'fun', ..., nan, nan, nan], dtype=object)

# %%
tfidf_vectorizer = TfidfVectorizer()
x = tfidf_vectorizer.fit_transform(movie_tags.astype('U'))
tfidf_vectorizer.vocabulary_
# Out:
# {'pixar': 1187,
#  'fun': 609,
#  'fantasy': 548,
#  'magic': 952,
#  'board': 187,
#  'game': 617,
#  'robin': 1308,
#  'williams': 1715,
#  'moldy': 1023,
#  'old': 1121,
#  'nan': 1065,
#  'pregnancy': 1217,
#  'remake': 1280,
#  'politics': 1201,
#  'president': 1220,
#  'mafia': 950,
#  'jane': 837,
#  'austen': 116,
#  'hollywood': 736,
#  'serial': 1380,
#  'killer': 879,
#  'alcoholism': 50,
#  'shakespeare': 1390,
#  'in': 785,
#  'netflix': 1084,
#  'queue': 1246,
#  'kidnapping': 877,
#  'high': 719,
#  'school': 1354,
#  'teacher': 1538,
#  'time': 1579,
#  'travel': 1605,
#  'brad': 204,
#  'pitt': 1186,
#  'bruce': 221,
#  'willis': 1716,
#  'mindfuck': 1011,
#  'post': 1208,
#  'apocalyptic': 88,
#  'twist': 1622,
#  'ending': 507,
#  'animal': 77,
#  'movie': 1045,
#  'pigs': 1184,
#  'villain': 1665,
#  'nonexistent': 1100,
#  'or': 1130,
#  'not': 1107,
#  'needed': 1076,
#  'for': 586,
#  'good': 649,
#  'story': 1481,
#  'death': 414,
#  'penalty': 1168,
#  'nun': 1111,
#  'twins': 1621,
#  'chick': 283,
#  'flick': 582,
#  'funny': 610,
#  'paul': 1163,
#  'rudd': 1323,
#  'quotable': 1250,
#  'seen': 1374,
#  'more': 1032,
#  'than': 1556,
#  'once': 1126,
#  'emma': 503,
#  'south': 1443,
#  'africa': 40,
#  'england': 509,
#  'journalism': 861,
#  'wedding': 1693,
#  'mystery': 1059,
#  'suspense': 1518,
#  'thriller': 1571,
#  'tricky': 1610,
#  'heist': 708,
#  'adoption': 31,
#  'prostitution': 1229,
#  'writing': 1732,
#  'music': 1057,
#  'jekyll': 845,
#  'and': 69,
#  'hyde': 769,
#  'theater': 1560,
#  'crime': 376,
#  'off': 1117,
#  'beat': 147,
#  'comedy': 329,
#  'quirky': 1249,
#  'test': 1555,
#  'tag': 1532,
#  'golf': 647,
#  'adam': 26,
#  'sandler': 1339,
#  'muppets': 1053,
#  'beautiful': 149,
#  'scenery': 1350,
#  'epic': 518,
#  'historical': 727,
#  'inspirational': 804,
#  'medieval': 986,
#  'mel': 988,
#  'gibson': 639,
#  'oscar': 1138,
#  'best': 161,
#  'cinematography': 302,
#  'revenge': 1289,
#  'sword': 1527,
#  'fight': 568,
#  'scotland': 1362,
#  'assassination': 106,
#  'holocaust': 737,
#  'dating': 404,
#  'addiction': 29,
#  'heroin': 717,
#  'leonardo': 908,
#  'dicaprio': 430,
#  'mark': 963,
#  'wahlberg': 1676,
#  'moon': 1029,
#  'nasa': 1070,
#  'space': 1445,
#  'superhero': 1509,
#  'michael': 1002,
#  'crichton': 375,
#  'submarine': 1499,
#  'controversial': 348,
#  'new': 1085,
#  'york': 1735,
#  'city': 304,
#  'nudity': 1110,
#  'full': 608,
#  'frontal': 604,
#  'computers': 336,
#  'made': 949,
#  'me': 982,
#  'cry': 385,
#  'generation': 629,
#  'stop': 1479,
#  'looking': 929,
#  'at': 110,
#  'swan': 1522,
#  'ireland': 820,
#  'cynical': 394,
#  'hilarious': 722,
#  'independent': 788,
#  'film': 573,
#  'witty': 1724,
#  'mental': 995,
#  'illness': 774,
#  'psychology': 1235,
#  'stephen': 1470,
#  'king': 881,
#  'business': 234,
#  'basketball': 141,
#  'france': 592,
#  'infertility': 796,
#  'australia': 118,
#  'bad': 133,
#  'sinbad': 1409,
#  'beethoven': 155,
#  'einstein': 497,
#  'court': 363,
#  'classic': 310,
#  'action': 23,
#  'sci': 1356,
#  'fi': 565,
#  'great': 661,
#  'soundtrack': 1442,
#  'engrossing': 510,
#  'adventure': 37,
#  'nerd': 1082,
#  'oldie': 1122,
#  'but': 236,
#  'goodie': 650,
#  'star': 1465,
#  'wars': 1683,
#  'robots': 1309,
#  'androids': 72,
#  'darth': 403,
#  'vader': 1649,
#  'luke': 941,
#  'skywalker': 1418,
#  'opera': 1129,
#  'louisa': 935,
#  'may': 976,
#  'alcott': 51,
#  'girl': 641,
#  'power': 1212,
#  'india': 789,
#  'gothic': 655,
#  'christmas': 295,
#  'prison': 1224,
#  'disability': 441,
#  'brutality': 223,
#  'dark': 402,
#  'psychedelic': 1232,
#  'satire': 1341,
#  'stylized': 1498,
#  'assassin': 105,
#  'jean': 843,
#  'reno': 1284,
#  'hit': 729,
#  'men': 993,
#  'assassins': 107,
#  'awkward': 127,
#  'romance': 1316,
#  'corruption': 358,
#  'disturbing': 447,
#  'drama': 469,
#  'french': 600,
#  'friendship': 602,
#  'gary': 625,
#  'oldman': 1123,
#  'acting': 22,
#  'guns': 675,
#  'hitman': 731,
#  'humorous': 765,
#  'imdb': 780,
#  'top': 1591,
#  '250': 9,
#  'lolita': 924,
#  'theme': 1561,
#  'loneliness': 925,
#  'love': 936,
#  'luc': 938,
#  'besson': 160,
#  'natalie': 1071,
#  'portman': 1207,
#  'organized': 1134,
#  'police': 1199,
#  'sniper': 1427,
#  'tense': 1551,
#  'touching': 1594,
#  'unique': 1635,
#  'dialogue': 428,
#  'non': 1099,
#  'linear': 918,
#  'cult': 388,
#  'drugs': 476,
#  'quentin': 1245,
#  'tarantino': 1536,
#  '1990s': 7,
#  'achronological': 21,
#  'packed': 1146,
#  'aggressive': 43,
#  'amazing': 60,
#  'dialogues': 429,
#  'anthology': 83,
#  'atmospheric': 112,
#  'awesome': 126,
#  'ass': 104,
#  'language': 895,
#  'bible': 164,
#  'biblical': 165,
#  'references': 1274,
#  'big': 166,
#  'boys': 203,
#  'with': 1722,
#  'name': 1064,
#  'actors': 24,
#  'black': 176,
#  'humor': 764,
#  'humour': 766,
#  'blood': 181,
#  'splatters': 1457,
#  'bloody': 183,
#  'casual': 261,
#  'violence': 1666,
#  'character': 271,
#  'development': 425,
#  'characters': 273,
#  'coke': 321,
#  'conversation': 350,
#  'cool': 351,
#  'style': 1496,
#  'scene': 1349,
#  'scrubbing': 1367,
#  'dance': 398,
#  'dancing': 399,
#  'different': 434,
#  'diner': 435,
#  'disjointed': 445,
#  'timeline': 1580,
#  'drug': 475,
#  'overdose': 1142,
#  'ensemble': 513,
#  'cast': 260,
#  'entertaining': 516,
#  'entirely': 517,
#  'episodic': 519,
#  'exciting': 535,
#  'fast': 551,
#  'paced': 1144,
#  'noir': 1096,
#  'foul': 591,
#  'gangster': 620,
#  'gangsters': 621,
#  'genius': 630,
#  'golden': 646,
#  'watch': 1686,
#  'gore': 653,
#  'gritty': 667,
#  'harvey': 697,
#  'keitel': 875,
#  'highly': 720,
#  'homosexuality': 740,
#  'iconic': 771,
#  'innovative': 799,
#  'intellectual': 807,
#  'intelligent': 809,
#  'intense': 810,
#  'interesting': 812,
#  'intertwining': 814,
#  'storylines': 1483,
#  'interwoven': 815,
#  'ironic': 821,
#  'irony': 822,
#  'john': 851,
#  'travolta': 1606,
#  'as': 103,
#  'protagonist': 1230,
#  'los': 932,
#  'angeles': 74,
#  'masterpiece': 971,
#  'meaningless': 983,
#  'milkshake': 1008,
#  'mobster': 1019,
#  'mobsters': 1020,
#  'monologue': 1025,
#  'motherfucker': 1039,
#  'multiple': 1052,
#  'stories': 1480,
#  'neo': 1081,
#  'nonlinear': 1101,
#  'narrative': 1069,
#  'storyline': 1482,
#  'notable': 1108,
#  'offensive': 1118,
#  'organised': 1132,
#  'original': 1135,
#  'plot': 1193,
#  'out': 1140,
#  'of': 1116,
#  'order': 1131,
#  'palme': 1151,
#  'parody': 1159,
#  'philosophical': 1177,
#  'pop': 1205,
#  'culture': 389,
#  'psychological': 1234,
#  'pulp': 1239,
#  'violent': 1667,
#  'content': 347,
#  'including': 787,
#  'rape': 1261,
#  'images': 776,
#  'graphic': 660,
#  'sexuality': 1387,
#  'some': 1437,
#  'strong': 1491,
#  'sustained': 1521,
#  'random': 1258,
#  'retro': 1287,
#  'roger': 1311,
#  'avary': 123,
#  'royal': 1321,
#  'cheese': 279,
#  'samuel': 1337,
#  'jackson': 833,
#  'sarcasm': 1340,
#  'sexy': 1388,
#  'smart': 1425,
#  'sophisticated': 1440,
#  'splatter': 1456,
#  'steve': 1471,
#  'buscemi': 233,
#  'storytelling': 1484,
#  'stylish': 1497,
#  'thought': 1569,
#  'provoking': 1231,
#  'uma': 1625,
#  'thurman': 1574,
#  'unpredictable': 1640,
#  'unusual': 1642,
#  'very': 1658,
#  'tv': 1620,
#  'marriage': 965,
#  'wrongful': 1733,
#  'imprisonment': 784,
#  'morgan': 1033,
#  'freeman': 599,
#  'enterprise': 514,
#  'coma': 328,
#  'weddings': 1694,
#  'cross': 380,
#  'dressing': 473,
#  'drag': 468,
#  'remade': 1279,
#  'tom': 1589,
#  'clancy': 307,
#  'grisham': 666,
#  'interracial': 813,
#  'shrimp': 1402,
#  'vietnam': 1662,
#  'bubba': 224,
#  'gump': 672,
#  'lieutenant': 915,
#  'dan': 397,
#  'stupid': 1495,
#  'is': 824,
#  'does': 455,
#  'bittersweet': 173,
#  'emotional': 504,
#  'heartwarming': 706,
#  'gambling': 616,
#  'disney': 446,
#  'animated': 78,
#  'feature': 557,
#  'score': 1360,
#  'bus': 232,
#  'spies': 1455,
#  'christina': 294,
#  'ricci': 1293,
#  'christopher': 297,
#  'lloyd': 923,
#  'family': 547,
#  'edith': 492,
#  'wharton': 1703,
#  'horses': 749,
#  'actress': 25,
#  'al': 46,
#  'pacino': 1145,
#  'based': 140,
#  'on': 1125,
#  'show': 1401,
#  'hula': 761,
#  'hoop': 741,
#  'biopic': 171,
#  'dinosaur': 437,
#  'japan': 838,
#  'divorce': 449,
#  'aids': 45,
#  'radio': 1256,
#  'butler': 237,
#  'housekeeper': 755,
#  'military': 1007,
#  'racism': 1254,
#  'football': 585,
#  'moving': 1047,
#  'true': 1614,
#  'biography': 170,
#  'chess': 282,
#  'lewis': 912,
#  'large': 896,
#  'race': 1252,
#  'empire': 505,
#  'state': 1467,
#  'building': 228,
#  'artificial': 97,
#  'intelligence': 808,
#  'cyberpunk': 392,
#  'future': 611,
#  'philip': 1176,
#  'dick': 432,
#  'dreamlike': 470,
#  'existentialism': 537,
#  'poetry': 1196,
#  'halloween': 680,
#  'knights': 886,
#  'adolescence': 30,
#  'overrated': 1143,
#  'apocalypse': 87,
#  'arnold': 93,
#  'schwarzenegger': 1355,
#  'nuclear': 1109,
#  'war': 1681,
#  'scifi': 1359,
#  'american': 62,
#  'indians': 791,
#  'native': 1073,
#  'americans': 63,
#  'hannibal': 686,
#  'lector': 905,
#  'coen': 320,
#  'brothers': 220,
#  'edward': 493,
#  'norton': 1105,
#  'priest': 1222,
#  'babies': 129,
#  'gulf': 671,
#  'spoof': 1458,
#  'bugs': 227,
#  'bunny': 230,
#  'veterinarian': 1659,
#  'aardman': 13,
#  'alcatraz': 49,
#  'bay': 144,
#  'terrorism': 1554,
#  'disaster': 443,
#  'aliens': 54,
#  'atomic': 113,
#  'bomb': 191,
#  'purity': 1240,
#  'essence': 522,
#  'slim': 1422,
#  'pickens': 1182,
#  'book': 194,
#  'narrated': 1068,
#  'abuse': 18,
#  'adultery': 36,
#  'give': 642,
#  'back': 131,
#  'my': 1058,
#  'son': 1439,
#  'it': 828,
#  'was': 1684,
#  'melodramatic': 991,
#  'kind': 880,
#  'dumb': 479,
#  'the': 1559,
#  'cinema': 301,
#  'capote': 250,
#  'falling': 545,
#  'alfred': 52,
#  'hitchcock': 730,
#  'james': 836,
#  'stewart': 1473,
#  'voyeurism': 1674,
#  'photographer': 1180,
#  'photography': 1181,
#  'screwball': 1365,
#  'brooch': 218,
#  'mount': 1043,
#  'rushmore': 1326,
#  'start': 1466,
#  'statue': 1469,
#  'george': 633,
#  'bernard': 158,
#  'shaw': 1393,
#  'rich': 1294,
#  'guy': 676,
#  'poor': 1203,
#  'italy': 829,
#  'royalty': 1322,
#  '1900s': 1,
#  'dorothy': 461,
#  'toto': 1593,
#  'civil': 305,
#  'television': 1549,
#  'movies': 1046,
#  'eerie': 494,
#  'rosebud': 1320,
#  'hal': 678,
#  'apes': 86,
#  'arthur': 96,
#  'clarke': 308,
#  'computer': 335,
#  'confusing': 340,
#  'dull': 477,
#  'futuristic': 612,
#  'meditative': 987,
#  'effects': 495,
#  'visual': 1670,
#  'relaxing': 1277,
#  'revolutionary': 1291,
#  'setting': 1383,
#  'ship': 1396,
#  'slow': 1423,
#  'spacecraft': 1446,
#  'stanley': 1463,
#  'kubrick': 887,
#  'superb': 1507,
#  'surreal': 1515,
#  'technology': 1543,
#  'tedious': 1544,
#  'visually': 1671,
#  'appealing': 89,
#  'mrs': 1050,
#  'dewinter': 426,
#  'europe': 526,
#  'amnesia': 65,
#  'cold': 322,
#  'russia': 1328,
#  'swashbuckler': 1524,
#  'ghosts': 636,
#  'shangri': 1391,
#  'la': 891,
#  'astaire': 108,
#  'rogers': 1312,
#  'homeless': 739,
#  'oil': 1120,
#  'nick': 1087,
#  'nora': 1103,
#  'charles': 274,
#  'leopard': 909,
#  'fugitive': 607,
#  'zombies': 1743,
#  'missionary': 1016,
#  'tennessee': 1550,
#  'hemingway': 710,
#  'food': 584,
#  'nanny': 1066,
#  'hammerstein': 683,
#  'updated': 1644,
#  'classics': 311,
#  'anti': 85,
#  'semitism': 1377,
#  'governess': 656,
#  'fish': 581,
#  'religion': 1278,
#  '1920s': 2,
#  '1960s': 4,
#  'jim': 850,
#  'morrison': 1034,
#  'predictable': 1215,
#  'navy': 1074,
#  '1950s': 3,
#  'freedom': 598,
#  'expression': 538,
#  'aging': 44,
#  'clousseau': 319,
#  'british': 209,
#  'monty': 1027,
#  'python': 1242,
#  'boxing': 202,
#  'jack': 830,
#  'nicholson': 1086,
#  'am': 59,
#  'your': 1738,
#  'father': 553,
#  'lucas': 939,
#  'harrison': 694,
#  'ford': 588,
#  'sequel': 1379,
#  'inigo': 798,
#  'montoya': 1026,
#  'six': 1415,
#  'fingered': 578,
#  'man': 957,
#  'archaeology': 91,
#  'indiana': 790,
#  'jones': 858,
#  'steven': 1472,
#  'spielberg': 1454,
#  'treasure': 1607,
#  'hunt': 768,
#  'ark': 92,
#  'covenant': 365,
#  'horror': 748,
#  'craft': 366,
#  'spaghetti': 1448,
#  'western': 1701,
#  'claustrophobic': 312,
#  'confrontational': 339,
#  'earnest': 485,
#  'screenplay': 1364,
#  'motivational': 1041,
#  'middle': 1004,
#  'east': 487,
#  'brainwashing': 206,
#  'harper': 691,
#  'lee': 906,
#  'ferris': 562,
#  'wheel': 1705,
#  'venice': 1654,
#  'zither': 1740,
#  'samurai': 1338,
#  'suspenseful': 1519,
#  'norman': 1104,
#  'bates': 142,
#  'white': 1707,
#  'saturday': 1343,
#  'night': 1089,
#  'live': 922,
#  'mozart': 1049,
#  'salieri': 1334,
#  'entertainer': 515,
#  'december': 416,
#  'cerebral': 267,
#  'reflective': 1275,
#  'special': 1449,
#  'sort': 1441,
#  'highschool': 721,
#  'simon': 1407,
#  'garfunkel': 624,
#  'pow': 1211,
#  'incest': 786,
#  'skiing': 1417,
#  'chilly': 288,
#  'creepy': 374,
#  'menacing': 994,
#  'oninous': 1128,
#  'murder': 1054,
#  'world': 1731,
#  'ii': 773,
#  'animation': 79,
#  'anime': 80,
#  'stunning': 1494,
#  'nazis': 1075,
#  'gunfight': 674,
#  'hammett': 684,
#  'heavy': 707,
#  'metal': 998,
#  'mockumentary': 1021,
#  'holy': 738,
#  'grail': 659,
#  'forster': 590,
#  'cambodia': 241,
#  'baseball': 139,
#  'birds': 172,
#  'juliette': 866,
#  'martin': 967,
#  'scorsese': 1361,
#  'robert': 1307,
#  'de': 409,
#  'niro': 1093,
#  'lawyer': 902,
#  'prom': 1227,
#  'vampires': 1651,
#  'demons': 418,
#  'personals': 1173,
#  'ads': 34,
#  'borg': 196,
#  'ex': 534,
#  'con': 337,
#  'miller': 1009,
#  'dogs': 456,
#  'klingons': 885,
#  'captain': 251,
#  'kirk': 883,
#  'whales': 1702,
#  'shark': 1392,
#  'sports': 1459,
#  'spying': 1460,
#  'slasher': 1419,
#  'hawkeye': 700,
#  'fennimore': 560,
#  'cooper': 352,
#  'conan': 338,
#  'andrew': 70,
#  'weber': 1692,
#  'jungle': 867,
#  'tolstoy': 1588,
#  'reunion': 1288,
#  'ballroom': 136,
#  'dinosaurs': 438,
#  'romantic': 1318,
#  'transplants': 1603,
#  '1970s': 5,
#  'queen': 1244,
#  'victoria': 1660,
#  'lawyers': 903,
#  'henry': 711,
#  'amish': 64,
#  'alternate': 58,
#  'universe': 1636,
#  'savannah': 1344,
#  'canada': 247,
#  'shipwreck': 1398,
#  'kevin': 876,
#  'costner': 359,
#  'bowling': 201,
#  'deadpan': 411,
#  'jeff': 844,
#  'bridges': 207,
#  'goodman': 651,
#  'julianne': 865,
#  'moore': 1030,
#  'marijuana': 961,
#  'seymour': 1389,
#  'hoffman': 732,
#  'ransom': 1259,
#  'rug': 1325,
#  'satirical': 1342,
#  'dickens': 433,
#  '1980s': 6,
#  'no': 1094,
#  'dvd': 482,
#  'conspiracy': 343,
#  'avant': 122,
#  'garde': 623,
#  'elegiac': 500,
#  'melancholy': 990,
#  'wry': 1734,
#  'hallucinatory': 681,
#  'paranoid': 1154,
#  'mathematics': 973,
#  'artsy': 101,
#  'enigmatic': 511,
#  'insanity': 801,
#  'paranoia': 1153,
#  'ben': 156,
#  'stiller': 1474,
#  'crude': 383,
#  'goofy': 652,
#  'ships': 1397,
#  'judaism': 863,
#  'huey': 758,
#  'long': 927,
#  'penn': 1169,
#  'warren': 1682,
#  'coulda': 362,
#  'been': 153,
#  'contender': 346,
#  'gangs': 619,
#  'olympics': 1124,
#  'china': 289,
#  'autism': 119,
#  'rasicm': 1262,
#  'jason': 840,
#  'california': 240,
#  'mexico': 1000,
#  'katzanzakis': 871,
#  'andy': 73,
#  'garcia': 622,
#  'francis': 594,
#  'coppola': 354,
#  'general': 628,
#  'motors': 1042,
#  'michigan': 1003,
#  'memory': 992,
#  'suburbia': 1501,
#  'carnival': 253,
#  'ray': 1264,
#  'bradbury': 205,
#  'mermaid': 996,
#  'weather': 1691,
#  'forecaster': 589,
#  'hinton': 724,
#  'tolkein': 1586,
#  'mice': 1001,
#  'college': 325,
#  'scary': 1347,
#  'aquarium': 90,
#  'boston': 198,
#  'capone': 249,
#  'survival': 1517,
#  'small': 1424,
#  'towns': 1595,
#  'train': 1600,
#  'eyes': 540,
#  'dobbler': 450,
#  'freaks': 596,
#  'snl': 1429,
#  'broadway': 212,
#  'poignant': 1197,
#  'sentimental': 1378,
#  'tear': 1541,
#  'jerker': 847,
#  'tearjerking': 1542,
#  'america': 61,
#  'cameo': 243,
#  'whoopi': 1708,
#  'goldberg': 645,
#  'trek': 1608,
#  'moses': 1037,
#  'martial': 966,
#  'arts': 100,
#  'mail': 954,
#  'doctors': 452,
#  'hungary': 767,
#  'stapler': 1464,
#  'workplace': 1730,
#  'nicolas': 1088,
#  'cage': 239,
#  'evil': 531,
#  'children': 286,
#  'siam': 1404,
#  'philosophy': 1178,
#  'nolan': 1097,
#  'directorial': 440,
#  'debut': 415,
#  'southern': 1444,
#  'us': 1646,
#  'golfing': 648,
#  'virtual': 1669,
#  'reality': 1267,
#  'motherhood': 1040,
#  'comic': 330,
#  'prequel': 1219,
#  'force': 587,
#  'endings': 508,
#  'spiders': 1453,
#  'adult': 35,
#  'free': 597,
#  'speech': 1451,
#  'park': 1157,
#  'trey': 1609,
#  'parker': 1158,
#  'chris': 291,
#  'klein': 884,
#  'biggs': 167,
#  'pizza': 1188,
#  'beer': 154,
#  'seann': 1369,
#  'william': 1714,
#  'scott': 1363,
#  'teen': 1545,
#  'claims': 306,
#  'to': 1582,
#  'be': 145,
#  'video': 1661,
#  'crucifixion': 382,
#  'rome': 1319,
#  'slavery': 1420,
#  'gentle': 632,
#  'lyrical': 943,
#  'nostalgia': 1106,
#  'see': 1372,
#  'dead': 410,
#  'people': 1170,
#  'aviation': 124,
#  'beatles': 148,
#  'river': 1301,
#  'academy': 19,
#  'award': 125,
#  'supporting': 1511,
#  'indonesia': 794,
#  'nightclub': 1090,
#  'island': 825,
#  'macaulay': 944,
#  'culkin': 387,
#  'challenging': 269,
#  'chuck': 298,
#  'palahniuk': 1149,
#  'clever': 314,
#  'complicated': 333,
#  'consumerism': 344,
#  'david': 405,
#  'fincher': 577,
#  'double': 462,
#  'life': 916,
#  'fighting': 569,
#  'helena': 709,
#  'bonham': 193,
#  'carter': 255,
#  'imaginary': 777,
#  'friend': 601,
#  'mind': 1010,
#  'blowing': 185,
#  'topless': 1592,
#  'palahnuik': 1150,
#  'postmodern': 1209,
#  'powerful': 1213,
#  'schizophrenia': 1353,
#  'social': 1431,
#  'commentary': 332,
#  'societal': 1432,
#  'criticism': 379,
#  'lawn': 900,
#  'mower': 1048,
#  'studio': 1492,
#  'ghibli': 634,
#  'tobacco': 1583,
#  'marathon': 959,
#  'class': 309,
#  'aykroyd': 128,
#  'camp': 245,
#  'irreverent': 823,
#  'jay': 841,
#  'silent': 1405,
#  'bob': 188,
#  'smith': 1426,
#  'up': 1643,
#  'series': 1381,
#  'ichabod': 770,
#  'crane': 368,
#  'depression': 422,
#  'dust': 481,
#  'bowl': 200,
#  'hanks': 685,
#  'graham': 658,
#  'greene': 663,
#  'downbeat': 464,
#  'fatherhood': 554,
#  'kaufman': 872,
#  'jude': 864,
#  'law': 899,
#  'obsession': 1113,
#  'secrets': 1371,
#  'asylum': 109,
#  'brittany': 211,
#  'murphy': 1055,
#  'hospital': 750,
#  'winona': 1720,
#  'ryder': 1330,
#  'dingo': 436,
#  'ate': 111,
#  'baby': 130,
#  'nuns': 1112,
#  'plastic': 1191,
#  'surgery': 1513,
#  'gun': 673,
#  'fu': 605,
#  'heroic': 716,
#  'bloodshed': 182,
#  'crazy': 370,
#  'figure': 570,
#  ...}

# %%
median = ratings.groupby('movieId')[['rating']].median()
tags ['tag'] = tags ['tag'] + ' '
tag = tags.groupby('movieId')[['tag']].sum()
median
# Out:
#          rating
# movieId
# 1           4.0
# 2           3.5
# 3           3.0
# 4           3.0
# 5           3.0
# ...         ...
# 193581      4.0
# 193583      3.5
# 193585      3.5
# 193587      3.5
# 193609      4.0
#
# [9724 rows x 1 columns]

# %%
movies_and_median = median.join(movies.set_index('movieId'), on='movieId')
movies_tags= tag.join(movies_and_median, on='movieId')
movies_tags
# Out:
#                                                       tag  rating  \
# movieId
# 1                                        pixar pixar fun      4.0
# 2           fantasy magic board game Robin Williams game      3.5
# 3                                              moldy old      3.0
# 5                                       pregnancy remake      3.0
# 7                                                 remake      3.0
# ...                                                   ...     ...
# 183611                       Comedy funny Rachel McAdams      4.0
# 184471   adventure Alicia Vikander video game adaptation      3.0
# 187593                 Josh Brolin Ryan Reynolds sarcasm      4.0
# 187595                           Emilia Clarke star wars      4.0
# 193565                     anime comedy gintama remaster      3.5
#
#                                       title  \
# movieId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 5        Father of the Bride Part II (1995)
# 7                            Sabrina (1995)
# ...                                     ...
# 183611                    Game Night (2018)
# 184471                   Tomb Raider (2018)
# 187593                    Deadpool 2 (2018)
# 187595       Solo: A Star Wars Story (2018)
# 193565            Gintama: The Movie (2010)
#
#                                               genres
# movieId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 5                                             Comedy
# 7                                     Comedy|Romance
# ...                                              ...
# 183611                    Action|Comedy|Crime|Horror
# 184471                      Action|Adventure|Fantasy
# 187593                          Action|Comedy|Sci-Fi
# 187595              Action|Adventure|Children|Sci-Fi
# 193565                Action|Animation|Comedy|Sci-Fi
#
# [1572 rows x 4 columns]

# %% [markdown]
# ## Выбираем пользователя и считываем Id фильмов, которые он смотрел и оценил выше 3.0

# %%
df_user = ratings.query(('userId == 505 '))
df_user = df_user.query(('rating >= 3.0 '))
del df_user['rating']
del df_user['userId']
del df_user['timestamp']
df_user
# Out:
#        movieId
# 80255       47
# 80256      273
# 80259      593
# 80260      968
# 80261     1022
# 80262     1029
# 80263     1033
# 80264     1215
# 80265     1241
# 80266     1261
# 80267     1969
# 80268     2083
# 80269     2087
# 80270     2959
# 80271     3039
# 80272     3461
# 80273     3476
# 80274     4105
# 80275     4226
# 80276     6502
# 80277     6731
# 80278     7360
# 80279     7387
# 80280     8874
# 80281    48780
# 80282    54999
# 80284    71535
# 80285    74685

# %%
df_user_tag = df_user.join(movies_tags, on='movieId')
df_user_tag
# Out:
#        movieId                                                tag  rating  \
# 80255       47                mystery twist ending serial killer     4.00
# 80256      273                                            gothic     3.00
# 80259      593  Hannibal Lector disturbing drama gothic psycho...    4.00
# 80260      968                                           zombies     4.00
# 80261     1022                                            Disney     3.25
# 80262     1029                                            Disney     3.50
# 80263     1033                                            Disney     3.50
# 80264     1215                                                NaN     NaN
# 80265     1241                                                NaN     NaN
# 80266     1261                                                NaN     NaN
# 80267     1969                                                NaN     NaN
# 80268     2083                                                NaN     NaN
# 80269     2087                                                NaN     NaN
# 80270     2959  dark comedy psychology thought-provoking twist...    4.50
# 80271     3039                                 class Dan Aykroyd     4.00
# 80272     3461                                            island     3.00
# 80273     3476                                                NaN     NaN
# 80274     4105                                           zombies     4.00
# 80275     4226  dark Mindfuck nonlinear psychology twist endin...    4.50
# 80276     6502                                   zombies zombies     4.00
# 80277     6731                                                NaN     NaN
# 80278     7360                                                NaN     NaN
# 80279     7387                                                NaN     NaN
# 80280     8874                                           zombies     4.00
# 80281    48780                 ummarti2006 atmospheric enigmatic     4.00
# 80282    54999                                                NaN     NaN
# 80284    71535  Bill Murray dark comedy Emma Stone funny Jesse...    4.00
# 80285    74685                                                NaN     NaN
#
#                                                    title  \
# 80255                        Seven (a.k.a. Se7en) (1995)
# 80256  Mary Shelley's Frankenstein (Frankenstein) (1994)
# 80259                   Silence of the Lambs, The (1991)
# 80260                    Night of the Living Dead (1968)
# 80261                                  Cinderella (1950)
# 80262                                       Dumbo (1941)
# 80263                      Fox and the Hound, The (1981)
# 80264                                                NaN
# 80265                                                NaN
# 80266                                                NaN
# 80267                                                NaN
# 80268                                                NaN
# 80269                                                NaN
# 80270                                  Fight Club (1999)
# 80271                              Trading Places (1983)
# 80272                           Lord of the Flies (1963)
# 80273                                                NaN
# 80274                              Evil Dead, The (1981)
# 80275                                     Memento (2000)
# 80276                               28 Days Later (2002)
# 80277                                                NaN
# 80278                                                NaN
# 80279                                                NaN
# 80280                           Shaun of the Dead (2004)
# 80281                               Prestige, The (2006)
# 80282                                                NaN
# 80284                                  Zombieland (2009)
# 80285                                                NaN
#
#                                            genres
# 80255                            Mystery|Thriller
# 80256                         Drama|Horror|Sci-Fi
# 80259                       Crime|Horror|Thriller
# 80260                      Horror|Sci-Fi|Thriller
# 80261  Animation|Children|Fantasy|Musical|Romance
# 80262            Animation|Children|Drama|Musical
# 80263                    Animation|Children|Drama
# 80264                                         NaN
# 80265                                         NaN
# 80266                                         NaN
# 80267                                         NaN
# 80268                                         NaN
# 80269                                         NaN
# 80270                 Action|Crime|Drama|Thriller
# 80271                                      Comedy
# 80272                    Adventure|Drama|Thriller
# 80273                                         NaN
# 80274                     Fantasy|Horror|Thriller
# 80275                            Mystery|Thriller
# 80276                        Action|Horror|Sci-Fi
# 80277                                         NaN
# 80278                                         NaN
# 80279                                         NaN
# 80280                               Comedy|Horror
# 80281               Drama|Mystery|Sci-Fi|Thriller
# 80282                                         NaN
# 80284                        Action|Comedy|Horror
# 80285                                         NaN

# %% [markdown]
# ## Фильмы со схожей медианной оценкой, как и те, которые понравились пользователю

# %%
df_user_tag['rating'].fillna(0, inplace=True)
m = np.median(df_user_tag['rating'])
m
# Out:
# 3.125

# %%
m1 = movies_tags.query(('rating >=3'))
m1 = m1.query(('rating <= 3.25'))
m1
# Out:
#                                                        tag  rating  \
# movieId
# 3                                               moldy old     3.00
# 5                                        pregnancy remake     3.00
# 7                                                  remake     3.00
# 22                                          serial killer     3.00
# 31                                    high school teacher     3.00
# ...                                                    ...     ...
# 135536   Bad story Bad writing Batman Ben Affleck comic...    3.00
# 141890                                             Moving     3.00
# 176419               allegorical uncomfortable unsettling     3.25
# 180985                                          bad music     3.00
# 184471    adventure Alicia Vikander video game adaptation     3.00
#
#                                       title  \
# movieId
# 3                   Grumpier Old Men (1995)
# 5        Father of the Bride Part II (1995)
# 7                            Sabrina (1995)
# 22                           Copycat (1995)
# 31                   Dangerous Minds (1995)
# ...                                     ...
# 135536                 Suicide Squad (2016)
# 141890           Beasts of No Nation (2015)
# 176419                       Mother! (2017)
# 180985          The Greatest Showman (2017)
# 184471                   Tomb Raider (2018)
#
#                                       genres
# movieId
# 3                             Comedy|Romance
# 5                                     Comedy
# 7                             Comedy|Romance
# 22       Crime|Drama|Horror|Mystery|Thriller
# 31                                     Drama
# ...                                      ...
# 135536                   Action|Crime|Sci-Fi
# 141890                             Drama|War
# 176419         Drama|Horror|Mystery|Thriller
# 180985                                 Drama
# 184471              Action|Adventure|Fantasy
#
# [227 rows x 4 columns]

# %%
movie_genres1 = [change_string(g) for g in df_user_tag.genres.values.astype('U')]
movie_tags1 = [change_string(g) for g in df_user_tag.tag.values.astype('U')]

# %% [markdown]
# ## Ищем фильмы, ближайшие по жанру

# %%
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(movie_genres)
tfidf_vectorizer.vocabulary_
# Out:
# {'adventure': 1,
#  'animation': 2,
#  'children': 3,
#  'comedy': 4,
#  'fantasy': 8,
#  'romance': 15,
#  'drama': 7,
#  'action': 0,
#  'crime': 5,
#  'thriller': 17,
#  'horror': 10,
#  'mystery': 13,
#  'scifi': 16,
#  'war': 18,
#  'musical': 12,
#  'documentary': 6,
#  'imax': 11,
#  'western': 19,
#  'filmnoir': 9,
#  'nogenreslisted': 14}

# %%
X_tfidf2 = tfidf_vectorizer.transform(movie_genres1)
res1 = neigh.kneighbors(X_tfidf2, return_distance=True)
res1[1]
# Out:
# array([[2659, 4035, 3517, 7352, 2421,  221, 4902],
#        [5099, 5048,  235, 5053, 1028, 7282, 9032],
#        [9059, 6895, 8185, 6500,  510, 3946, 5093],
#        [8430, 1926, 1700, 4092, 2822, 1925, 1193],
#        [ 780, 7207,  812, 1550, 8723, 7907,  783],
#        [ 786, 5766, 6804, 1559, 3990, 7766,  782],
#        [1493, 6405,  790, 7510, 3938, 4230, 7552],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [6263, 6951,  307, 2744, 4752, 7236, 9594],
#        [2284, 5942, 8589, 5929, 8581, 2292, 5933],
#        [8977, 6884, 2055, 2156, 9069, 7454, 2589],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [1732, 8682, 7569, 6195, 3061, 4961, 7329],
#        [2659, 4035, 3517, 7352, 2421,  221, 4902],
#        [4408, 3941, 9332, 6650, 1275, 8762, 4595],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [4932, 9044, 6602, 7359,  654, 9042, 9061],
#        [7014, 5699, 3562, 6802, 6331, 5333, 8502],
#        [9286,   46, 3329, 6846,  831,  828, 1250],
#        [7154, 8434, 2451, 9035, 8565, 1620, 6858],
#        [9286,   46, 3329, 6846,  831,  828, 1250]], dtype=int64)

# %% [markdown]
# ## Ищем фильмы, ближайшие по тегам

# %%
movie_tags = [change_string1(g) for g in movies_tags.tag.values]

tfidf_vectorizer = TfidfVectorizer()
x = tfidf_vectorizer.fit_transform(movie_tags)
tfidf_vectorizer.vocabulary_
# Out:
# {'pixar': 1186,
#  'fun': 609,
#  'fantasy': 548,
#  'magic': 952,
#  'board': 187,
#  'game': 617,
#  'robin': 1307,
#  'williams': 1714,
#  'moldy': 1023,
#  'old': 1120,
#  'pregnancy': 1216,
#  'remake': 1279,
#  'politics': 1200,
#  'president': 1219,
#  'mafia': 950,
#  'jane': 837,
#  'austen': 116,
#  'hollywood': 736,
#  'serial': 1379,
#  'killer': 879,
#  'alcoholism': 50,
#  'shakespeare': 1389,
#  'in': 785,
#  'netflix': 1083,
#  'queue': 1245,
#  'kidnapping': 877,
#  'high': 719,
#  'school': 1353,
#  'teacher': 1537,
#  'time': 1578,
#  'travel': 1604,
#  'brad': 204,
#  'pitt': 1185,
#  'bruce': 221,
#  'willis': 1715,
#  'mindfuck': 1011,
#  'post': 1207,
#  'apocalyptic': 88,
#  'twist': 1621,
#  'ending': 507,
#  'animal': 77,
#  'movie': 1045,
#  'pigs': 1183,
#  'villain': 1664,
#  'nonexistent': 1099,
#  'or': 1129,
#  'not': 1106,
#  'needed': 1075,
#  'for': 586,
#  'good': 649,
#  'story': 1480,
#  'death': 414,
#  'penalty': 1167,
#  'nun': 1110,
#  'twins': 1620,
#  'chick': 283,
#  'flick': 582,
#  'funny': 610,
#  'paul': 1162,
#  'rudd': 1322,
#  'quotable': 1249,
#  'seen': 1373,
#  'more': 1032,
#  'than': 1555,
#  'once': 1125,
#  'emma': 503,
#  'south': 1442,
#  'africa': 40,
#  'england': 509,
#  'journalism': 861,
#  'wedding': 1692,
#  'mystery': 1059,
#  'suspense': 1517,
#  'thriller': 1570,
#  'tricky': 1609,
#  'heist': 708,
#  'adoption': 31,
#  'prostitution': 1228,
#  'writing': 1731,
#  'music': 1057,
#  'jekyll': 845,
#  'and': 69,
#  'hyde': 769,
#  'theater': 1559,
#  'crime': 376,
#  'off': 1116,
#  'beat': 147,
#  'comedy': 329,
#  'quirky': 1248,
#  'test': 1554,
#  'tag': 1531,
#  'golf': 647,
#  'adam': 26,
#  'sandler': 1338,
#  'muppets': 1053,
#  'beautiful': 149,
#  'scenery': 1349,
#  'epic': 518,
#  'historical': 727,
#  'inspirational': 804,
#  'medieval': 986,
#  'mel': 988,
#  'gibson': 639,
#  'oscar': 1137,
#  'best': 161,
#  'cinematography': 302,
#  'revenge': 1288,
#  'sword': 1526,
#  'fight': 568,
#  'scotland': 1361,
#  'assassination': 106,
#  'holocaust': 737,
#  'dating': 404,
#  'addiction': 29,
#  'heroin': 717,
#  'leonardo': 908,
#  'dicaprio': 430,
#  'mark': 963,
#  'wahlberg': 1675,
#  'moon': 1029,
#  'nasa': 1069,
#  'space': 1444,
#  'superhero': 1508,
#  'michael': 1002,
#  'crichton': 375,
#  'submarine': 1498,
#  'controversial': 348,
#  'new': 1084,
#  'york': 1734,
#  'city': 304,
#  'nudity': 1109,
#  'full': 608,
#  'frontal': 604,
#  'computers': 336,
#  'made': 949,
#  'me': 982,
#  'cry': 385,
#  'generation': 629,
#  'stop': 1478,
#  'looking': 929,
#  'at': 110,
#  'swan': 1521,
#  'ireland': 820,
#  'cynical': 394,
#  'hilarious': 722,
#  'independent': 788,
#  'film': 573,
#  'witty': 1723,
#  'mental': 995,
#  'illness': 774,
#  'psychology': 1234,
#  'stephen': 1469,
#  'king': 881,
#  'business': 234,
#  'basketball': 141,
#  'france': 592,
#  'infertility': 796,
#  'australia': 118,
#  'bad': 133,
#  'sinbad': 1408,
#  'beethoven': 155,
#  'einstein': 497,
#  'court': 363,
#  'classic': 310,
#  'action': 23,
#  'sci': 1355,
#  'fi': 565,
#  'great': 661,
#  'soundtrack': 1441,
#  'engrossing': 510,
#  'adventure': 37,
#  'nerd': 1081,
#  'oldie': 1121,
#  'but': 236,
#  'goodie': 650,
#  'star': 1464,
#  'wars': 1682,
#  'robots': 1308,
#  'androids': 72,
#  'darth': 403,
#  'vader': 1648,
#  'luke': 941,
#  'skywalker': 1417,
#  'opera': 1128,
#  'louisa': 935,
#  'may': 976,
#  'alcott': 51,
#  'girl': 641,
#  'power': 1211,
#  'india': 789,
#  'gothic': 655,
#  'christmas': 295,
#  'prison': 1223,
#  'disability': 441,
#  'brutality': 223,
#  'dark': 402,
#  'psychedelic': 1231,
#  'satire': 1340,
#  'stylized': 1497,
#  'assassin': 105,
#  'jean': 843,
#  'reno': 1283,
#  'hit': 729,
#  'men': 993,
#  'assassins': 107,
#  'awkward': 127,
#  'romance': 1315,
#  'corruption': 358,
#  'disturbing': 447,
#  'drama': 469,
#  'french': 600,
#  'friendship': 602,
#  'gary': 625,
#  'oldman': 1122,
#  'acting': 22,
#  'guns': 675,
#  'hitman': 731,
#  'humorous': 765,
#  'imdb': 780,
#  'top': 1590,
#  '250': 9,
#  'lolita': 924,
#  'theme': 1560,
#  'loneliness': 925,
#  'love': 936,
#  'luc': 938,
#  'besson': 160,
#  'natalie': 1070,
#  'portman': 1206,
#  'organized': 1133,
#  'police': 1198,
#  'sniper': 1426,
#  'tense': 1550,
#  'touching': 1593,
#  'unique': 1634,
#  'dialogue': 428,
#  'non': 1098,
#  'linear': 918,
#  'cult': 388,
#  'drugs': 476,
#  'quentin': 1244,
#  'tarantino': 1535,
#  '1990s': 7,
#  'achronological': 21,
#  'packed': 1145,
#  'aggressive': 43,
#  'amazing': 60,
#  'dialogues': 429,
#  'anthology': 83,
#  'atmospheric': 112,
#  'awesome': 126,
#  'ass': 104,
#  'language': 895,
#  'bible': 164,
#  'biblical': 165,
#  'references': 1273,
#  'big': 166,
#  'boys': 203,
#  'with': 1721,
#  'name': 1064,
#  'actors': 24,
#  'black': 176,
#  'humor': 764,
#  'humour': 766,
#  'blood': 181,
#  'splatters': 1456,
#  'bloody': 183,
#  'casual': 261,
#  'violence': 1665,
#  'character': 271,
#  'development': 425,
#  'characters': 273,
#  'coke': 321,
#  'conversation': 350,
#  'cool': 351,
#  'style': 1495,
#  'scene': 1348,
#  'scrubbing': 1366,
#  'dance': 398,
#  'dancing': 399,
#  'different': 434,
#  'diner': 435,
#  'disjointed': 445,
#  'timeline': 1579,
#  'drug': 475,
#  'overdose': 1141,
#  'ensemble': 513,
#  'cast': 260,
#  'entertaining': 516,
#  'entirely': 517,
#  'episodic': 519,
#  'exciting': 535,
#  'fast': 551,
#  'paced': 1143,
#  'noir': 1095,
#  'foul': 591,
#  'gangster': 620,
#  'gangsters': 621,
#  'genius': 630,
#  'golden': 646,
#  'watch': 1685,
#  'gore': 653,
#  'gritty': 667,
#  'harvey': 697,
#  'keitel': 875,
#  'highly': 720,
#  'homosexuality': 740,
#  'iconic': 771,
#  'innovative': 799,
#  'intellectual': 807,
#  'intelligent': 809,
#  'intense': 810,
#  'interesting': 812,
#  'intertwining': 814,
#  'storylines': 1482,
#  'interwoven': 815,
#  'ironic': 821,
#  'irony': 822,
#  'john': 851,
#  'travolta': 1605,
#  'as': 103,
#  'protagonist': 1229,
#  'los': 932,
#  'angeles': 74,
#  'masterpiece': 971,
#  'meaningless': 983,
#  'milkshake': 1008,
#  'mobster': 1019,
#  'mobsters': 1020,
#  'monologue': 1025,
#  'motherfucker': 1039,
#  'multiple': 1052,
#  'stories': 1479,
#  'neo': 1080,
#  'nonlinear': 1100,
#  'narrative': 1068,
#  'storyline': 1481,
#  'notable': 1107,
#  'offensive': 1117,
#  'organised': 1131,
#  'original': 1134,
#  'plot': 1192,
#  'out': 1139,
#  'of': 1115,
#  'order': 1130,
#  'palme': 1150,
#  'parody': 1158,
#  'philosophical': 1176,
#  'pop': 1204,
#  'culture': 389,
#  'psychological': 1233,
#  'pulp': 1238,
#  'violent': 1666,
#  'content': 347,
#  'including': 787,
#  'rape': 1260,
#  'images': 776,
#  'graphic': 660,
#  'sexuality': 1386,
#  'some': 1436,
#  'strong': 1490,
#  'sustained': 1520,
#  'random': 1257,
#  'retro': 1286,
#  'roger': 1310,
#  'avary': 123,
#  'royal': 1320,
#  'cheese': 279,
#  'samuel': 1336,
#  'jackson': 833,
#  'sarcasm': 1339,
#  'sexy': 1387,
#  'smart': 1424,
#  'sophisticated': 1439,
#  'splatter': 1455,
#  'steve': 1470,
#  'buscemi': 233,
#  'storytelling': 1483,
#  'stylish': 1496,
#  'thought': 1568,
#  'provoking': 1230,
#  'uma': 1624,
#  'thurman': 1573,
#  'unpredictable': 1639,
#  'unusual': 1641,
#  'very': 1657,
#  'tv': 1619,
#  'marriage': 965,
#  'wrongful': 1732,
#  'imprisonment': 784,
#  'morgan': 1033,
#  'freeman': 599,
#  'enterprise': 514,
#  'coma': 328,
#  'weddings': 1693,
#  'cross': 380,
#  'dressing': 473,
#  'drag': 468,
#  'remade': 1278,
#  'tom': 1588,
#  'clancy': 307,
#  'grisham': 666,
#  'interracial': 813,
#  'shrimp': 1401,
#  'vietnam': 1661,
#  'bubba': 224,
#  'gump': 672,
#  'lieutenant': 915,
#  'dan': 397,
#  'stupid': 1494,
#  'is': 824,
#  'does': 455,
#  'bittersweet': 173,
#  'emotional': 504,
#  'heartwarming': 706,
#  'gambling': 616,
#  'disney': 446,
#  'animated': 78,
#  'feature': 557,
#  'score': 1359,
#  'bus': 232,
#  'spies': 1454,
#  'christina': 294,
#  'ricci': 1292,
#  'christopher': 297,
#  'lloyd': 923,
#  'family': 547,
#  'edith': 492,
#  'wharton': 1702,
#  'horses': 749,
#  'actress': 25,
#  'al': 46,
#  'pacino': 1144,
#  'based': 140,
#  'on': 1124,
#  'show': 1400,
#  'hula': 761,
#  'hoop': 741,
#  'biopic': 171,
#  'dinosaur': 437,
#  'japan': 838,
#  'divorce': 449,
#  'aids': 45,
#  'radio': 1255,
#  'butler': 237,
#  'housekeeper': 755,
#  'military': 1007,
#  'racism': 1253,
#  'football': 585,
#  'moving': 1047,
#  'true': 1613,
#  'biography': 170,
#  'chess': 282,
#  'lewis': 912,
#  'large': 896,
#  'race': 1251,
#  'empire': 505,
#  'state': 1466,
#  'building': 228,
#  'artificial': 97,
#  'intelligence': 808,
#  'cyberpunk': 392,
#  'future': 611,
#  'philip': 1175,
#  'dick': 432,
#  'dreamlike': 470,
#  'existentialism': 537,
#  'poetry': 1195,
#  'halloween': 680,
#  'knights': 886,
#  'adolescence': 30,
#  'overrated': 1142,
#  'apocalypse': 87,
#  'arnold': 93,
#  'schwarzenegger': 1354,
#  'nuclear': 1108,
#  'war': 1680,
#  'scifi': 1358,
#  'american': 62,
#  'indians': 791,
#  'native': 1072,
#  'americans': 63,
#  'hannibal': 686,
#  'lector': 905,
#  'coen': 320,
#  'brothers': 220,
#  'edward': 493,
#  'norton': 1104,
#  'priest': 1221,
#  'babies': 129,
#  'gulf': 671,
#  'spoof': 1457,
#  'bugs': 227,
#  'bunny': 230,
#  'veterinarian': 1658,
#  'aardman': 13,
#  'alcatraz': 49,
#  'bay': 144,
#  'terrorism': 1553,
#  'disaster': 443,
#  'aliens': 54,
#  'atomic': 113,
#  'bomb': 191,
#  'purity': 1239,
#  'essence': 522,
#  'slim': 1421,
#  'pickens': 1181,
#  'book': 194,
#  'narrated': 1067,
#  'abuse': 18,
#  'adultery': 36,
#  'give': 642,
#  'back': 131,
#  'my': 1058,
#  'son': 1438,
#  'it': 828,
#  'was': 1683,
#  'melodramatic': 991,
#  'kind': 880,
#  'dumb': 479,
#  'the': 1558,
#  'cinema': 301,
#  'capote': 250,
#  'falling': 545,
#  'alfred': 52,
#  'hitchcock': 730,
#  'james': 836,
#  'stewart': 1472,
#  'voyeurism': 1673,
#  'photographer': 1179,
#  'photography': 1180,
#  'screwball': 1364,
#  'brooch': 218,
#  'mount': 1043,
#  'rushmore': 1325,
#  'start': 1465,
#  'statue': 1468,
#  'george': 633,
#  'bernard': 158,
#  'shaw': 1392,
#  'rich': 1293,
#  'guy': 676,
#  'poor': 1202,
#  'italy': 829,
#  'royalty': 1321,
#  '1900s': 1,
#  'dorothy': 461,
#  'toto': 1592,
#  'civil': 305,
#  'television': 1548,
#  'movies': 1046,
#  'eerie': 494,
#  'rosebud': 1319,
#  'hal': 678,
#  'apes': 86,
#  'arthur': 96,
#  'clarke': 308,
#  'computer': 335,
#  'confusing': 340,
#  'dull': 477,
#  'futuristic': 612,
#  'meditative': 987,
#  'effects': 495,
#  'visual': 1669,
#  'relaxing': 1276,
#  'revolutionary': 1290,
#  'setting': 1382,
#  'ship': 1395,
#  'slow': 1422,
#  'spacecraft': 1445,
#  'stanley': 1462,
#  'kubrick': 887,
#  'superb': 1506,
#  'surreal': 1514,
#  'technology': 1542,
#  'tedious': 1543,
#  'visually': 1670,
#  'appealing': 89,
#  'mrs': 1050,
#  'dewinter': 426,
#  'europe': 526,
#  'amnesia': 65,
#  'cold': 322,
#  'russia': 1327,
#  'swashbuckler': 1523,
#  'ghosts': 636,
#  'shangri': 1390,
#  'la': 891,
#  'astaire': 108,
#  'rogers': 1311,
#  'homeless': 739,
#  'oil': 1119,
#  'nick': 1086,
#  'nora': 1102,
#  'charles': 274,
#  'leopard': 909,
#  'fugitive': 607,
#  'zombies': 1742,
#  'missionary': 1016,
#  'tennessee': 1549,
#  'hemingway': 710,
#  'food': 584,
#  'nanny': 1065,
#  'hammerstein': 683,
#  'updated': 1643,
#  'classics': 311,
#  'anti': 85,
#  'semitism': 1376,
#  'governess': 656,
#  'fish': 581,
#  'religion': 1277,
#  '1920s': 2,
#  '1960s': 4,
#  'jim': 850,
#  'morrison': 1034,
#  'predictable': 1214,
#  'navy': 1073,
#  '1950s': 3,
#  'freedom': 598,
#  'expression': 538,
#  'aging': 44,
#  'clousseau': 319,
#  'british': 209,
#  'monty': 1027,
#  'python': 1241,
#  'boxing': 202,
#  'jack': 830,
#  'nicholson': 1085,
#  'am': 59,
#  'your': 1737,
#  'father': 553,
#  'lucas': 939,
#  'harrison': 694,
#  'ford': 588,
#  'sequel': 1378,
#  'inigo': 798,
#  'montoya': 1026,
#  'six': 1414,
#  'fingered': 578,
#  'man': 957,
#  'archaeology': 91,
#  'indiana': 790,
#  'jones': 858,
#  'steven': 1471,
#  'spielberg': 1453,
#  'treasure': 1606,
#  'hunt': 768,
#  'ark': 92,
#  'covenant': 365,
#  'horror': 748,
#  'craft': 366,
#  'spaghetti': 1447,
#  'western': 1700,
#  'claustrophobic': 312,
#  'confrontational': 339,
#  'earnest': 485,
#  'screenplay': 1363,
#  'motivational': 1041,
#  'middle': 1004,
#  'east': 487,
#  'brainwashing': 206,
#  'harper': 691,
#  'lee': 906,
#  'ferris': 562,
#  'wheel': 1704,
#  'venice': 1653,
#  'zither': 1739,
#  'samurai': 1337,
#  'suspenseful': 1518,
#  'norman': 1103,
#  'bates': 142,
#  'white': 1706,
#  'saturday': 1342,
#  'night': 1088,
#  'live': 922,
#  'mozart': 1049,
#  'salieri': 1333,
#  'entertainer': 515,
#  'december': 416,
#  'cerebral': 267,
#  'reflective': 1274,
#  'special': 1448,
#  'sort': 1440,
#  'highschool': 721,
#  'simon': 1406,
#  'garfunkel': 624,
#  'pow': 1210,
#  'incest': 786,
#  'skiing': 1416,
#  'chilly': 288,
#  'creepy': 374,
#  'menacing': 994,
#  'oninous': 1127,
#  'murder': 1054,
#  'world': 1730,
#  'ii': 773,
#  'animation': 79,
#  'anime': 80,
#  'stunning': 1493,
#  'nazis': 1074,
#  'gunfight': 674,
#  'hammett': 684,
#  'heavy': 707,
#  'metal': 998,
#  'mockumentary': 1021,
#  'holy': 738,
#  'grail': 659,
#  'forster': 590,
#  'cambodia': 241,
#  'baseball': 139,
#  'birds': 172,
#  'juliette': 866,
#  'martin': 967,
#  'scorsese': 1360,
#  'robert': 1306,
#  'de': 409,
#  'niro': 1092,
#  'lawyer': 902,
#  'prom': 1226,
#  'vampires': 1650,
#  'demons': 418,
#  'personals': 1172,
#  'ads': 34,
#  'borg': 196,
#  'ex': 534,
#  'con': 337,
#  'miller': 1009,
#  'dogs': 456,
#  'klingons': 885,
#  'captain': 251,
#  'kirk': 883,
#  'whales': 1701,
#  'shark': 1391,
#  'sports': 1458,
#  'spying': 1459,
#  'slasher': 1418,
#  'hawkeye': 700,
#  'fennimore': 560,
#  'cooper': 352,
#  'conan': 338,
#  'andrew': 70,
#  'weber': 1691,
#  'jungle': 867,
#  'tolstoy': 1587,
#  'reunion': 1287,
#  'ballroom': 136,
#  'dinosaurs': 438,
#  'romantic': 1317,
#  'transplants': 1602,
#  '1970s': 5,
#  'queen': 1243,
#  'victoria': 1659,
#  'lawyers': 903,
#  'henry': 711,
#  'amish': 64,
#  'alternate': 58,
#  'universe': 1635,
#  'savannah': 1343,
#  'canada': 247,
#  'shipwreck': 1397,
#  'kevin': 876,
#  'costner': 359,
#  'bowling': 201,
#  'deadpan': 411,
#  'jeff': 844,
#  'bridges': 207,
#  'goodman': 651,
#  'julianne': 865,
#  'moore': 1030,
#  'marijuana': 961,
#  'seymour': 1388,
#  'hoffman': 732,
#  'ransom': 1258,
#  'rug': 1324,
#  'satirical': 1341,
#  'dickens': 433,
#  '1980s': 6,
#  'no': 1093,
#  'dvd': 482,
#  'conspiracy': 343,
#  'avant': 122,
#  'garde': 623,
#  'elegiac': 500,
#  'melancholy': 990,
#  'wry': 1733,
#  'hallucinatory': 681,
#  'paranoid': 1153,
#  'mathematics': 973,
#  'artsy': 101,
#  'enigmatic': 511,
#  'insanity': 801,
#  'paranoia': 1152,
#  'ben': 156,
#  'stiller': 1473,
#  'crude': 383,
#  'goofy': 652,
#  'ships': 1396,
#  'judaism': 863,
#  'huey': 758,
#  'long': 927,
#  'penn': 1168,
#  'warren': 1681,
#  'coulda': 362,
#  'been': 153,
#  'contender': 346,
#  'gangs': 619,
#  'olympics': 1123,
#  'china': 289,
#  'autism': 119,
#  'rasicm': 1261,
#  'jason': 840,
#  'california': 240,
#  'mexico': 1000,
#  'katzanzakis': 871,
#  'andy': 73,
#  'garcia': 622,
#  'francis': 594,
#  'coppola': 354,
#  'general': 628,
#  'motors': 1042,
#  'michigan': 1003,
#  'memory': 992,
#  'suburbia': 1500,
#  'carnival': 253,
#  'ray': 1263,
#  'bradbury': 205,
#  'mermaid': 996,
#  'weather': 1690,
#  'forecaster': 589,
#  'hinton': 724,
#  'tolkein': 1585,
#  'mice': 1001,
#  'college': 325,
#  'scary': 1346,
#  'aquarium': 90,
#  'boston': 198,
#  'capone': 249,
#  'survival': 1516,
#  'small': 1423,
#  'towns': 1594,
#  'train': 1599,
#  'eyes': 540,
#  'dobbler': 450,
#  'freaks': 596,
#  'snl': 1428,
#  'broadway': 212,
#  'poignant': 1196,
#  'sentimental': 1377,
#  'tear': 1540,
#  'jerker': 847,
#  'tearjerking': 1541,
#  'america': 61,
#  'cameo': 243,
#  'whoopi': 1707,
#  'goldberg': 645,
#  'trek': 1607,
#  'moses': 1037,
#  'martial': 966,
#  'arts': 100,
#  'mail': 954,
#  'doctors': 452,
#  'hungary': 767,
#  'stapler': 1463,
#  'workplace': 1729,
#  'nicolas': 1087,
#  'cage': 239,
#  'evil': 531,
#  'children': 286,
#  'siam': 1403,
#  'philosophy': 1177,
#  'nolan': 1096,
#  'directorial': 440,
#  'debut': 415,
#  'southern': 1443,
#  'us': 1645,
#  'golfing': 648,
#  'virtual': 1668,
#  'reality': 1266,
#  'motherhood': 1040,
#  'comic': 330,
#  'prequel': 1218,
#  'force': 587,
#  'endings': 508,
#  'spiders': 1452,
#  'adult': 35,
#  'free': 597,
#  'speech': 1450,
#  'park': 1156,
#  'trey': 1608,
#  'parker': 1157,
#  'chris': 291,
#  'klein': 884,
#  'biggs': 167,
#  'pizza': 1187,
#  'beer': 154,
#  'seann': 1368,
#  'william': 1713,
#  'scott': 1362,
#  'teen': 1544,
#  'claims': 306,
#  'to': 1581,
#  'be': 145,
#  'video': 1660,
#  'crucifixion': 382,
#  'rome': 1318,
#  'slavery': 1419,
#  'gentle': 632,
#  'lyrical': 943,
#  'nostalgia': 1105,
#  'see': 1371,
#  'dead': 410,
#  'people': 1169,
#  'aviation': 124,
#  'beatles': 148,
#  'river': 1300,
#  'academy': 19,
#  'award': 125,
#  'supporting': 1510,
#  'indonesia': 794,
#  'nightclub': 1089,
#  'island': 825,
#  'macaulay': 944,
#  'culkin': 387,
#  'challenging': 269,
#  'chuck': 298,
#  'palahniuk': 1148,
#  'clever': 314,
#  'complicated': 333,
#  'consumerism': 344,
#  'david': 405,
#  'fincher': 577,
#  'double': 462,
#  'life': 916,
#  'fighting': 569,
#  'helena': 709,
#  'bonham': 193,
#  'carter': 255,
#  'imaginary': 777,
#  'friend': 601,
#  'mind': 1010,
#  'blowing': 185,
#  'topless': 1591,
#  'palahnuik': 1149,
#  'postmodern': 1208,
#  'powerful': 1212,
#  'schizophrenia': 1352,
#  'social': 1430,
#  'commentary': 332,
#  'societal': 1431,
#  'criticism': 379,
#  'lawn': 900,
#  'mower': 1048,
#  'studio': 1491,
#  'ghibli': 634,
#  'tobacco': 1582,
#  'marathon': 959,
#  'class': 309,
#  'aykroyd': 128,
#  'camp': 245,
#  'irreverent': 823,
#  'jay': 841,
#  'silent': 1404,
#  'bob': 188,
#  'smith': 1425,
#  'up': 1642,
#  'series': 1380,
#  'ichabod': 770,
#  'crane': 368,
#  'depression': 422,
#  'dust': 481,
#  'bowl': 200,
#  'hanks': 685,
#  'graham': 658,
#  'greene': 663,
#  'downbeat': 464,
#  'fatherhood': 554,
#  'kaufman': 872,
#  'jude': 864,
#  'law': 899,
#  'obsession': 1112,
#  'secrets': 1370,
#  'asylum': 109,
#  'brittany': 211,
#  'murphy': 1055,
#  'hospital': 750,
#  'winona': 1719,
#  'ryder': 1329,
#  'dingo': 436,
#  'ate': 111,
#  'baby': 130,
#  'nuns': 1111,
#  'plastic': 1190,
#  'surgery': 1512,
#  'gun': 673,
#  'fu': 605,
#  'heroic': 716,
#  'bloodshed': 182,
#  'crazy': 370,
#  'figure': 570,
#  'skating': 1415,
#  ...}

# %%
neigh1 = NearestNeighbors(n_neighbors=7, n_jobs=-1, metric='euclidean') 
neigh1.fit(x)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='euclidean',
#                  metric_params=None, n_jobs=-1, n_neighbors=7, p=2, radius=1.0)

# %%
X_tfidf3 = tfidf_vectorizer.transform(movie_tags1)
X_tfidf3
res2 = neigh1.kneighbors(X_tfidf3, return_distance=True)
res2[1]
# Out:
# array([[ 673,  990,   77,   51, 1216, 1104,  978],
#        [  69,  673,  990,  146,  510,  103, 1035],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [1241,  231,  782, 1028, 1383,  990,  673],
#        [ 246,  347,  243,  147,  247,  489,  149],
#        [ 246,  347,  243,  147,  247,  489,  149],
#        [ 246,  347,  243,  147,  247,  489,  149],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,  639,   77,  527,  722, 1216],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 714,  634,  673,  990,   77,  488, 1363],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [1241,  231,  782, 1028, 1383,  990,  673],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [1241,  231,  782, 1028, 1383,  990,  673],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978],
#        [ 673,  990,   77,   51, 1216, 1104,  978]], dtype=int64)

# %% [markdown]
# ## Соединим полученные массивы и найдем фильмы, которые упоминаются в них чаще всего.

# %%
a1 = res1[1].flatten()
a2 = res2[1].flatten()
a = a1 + a2
a
# Out:
# array([ 3332,  5025,  3594,  7403,  3637,  1325,  5880,  5168,  5721,
#         1225,  5199,  1538,  7385, 10067,  9732,  7885,  8262,  6551,
#         1726,  5050,  6071,  9671,  2157,  2482,  5120,  4205,  2915,
#         1866,  1026,  7554,  1055,  1697,  8970,  8396,   932,  1032,
#         6113,  7047,  1706,  4237,  8255,   931,  1739,  6752,  1033,
#         7657,  4185,  4719,  7701,  9959,  1036,  3406,  6897,  2047,
#         1932,  2228,  9959,  1036,  3406,  6897,  2047,  1932,  2228,
#         9959,  1036,  3406,  6897,  2047,  1932,  2228,  9959,  1036,
#         3406,  6897,  2047,  1932,  2228,  9959,  1036,  3406,  6897,
#         2047,  1932,  2228,  9959,  1036,  3406,  6897,  2047,  1932,
#         2228,  6936,  7941,   946,  2821,  5279,  7958, 10810,  2957,
#         6932,  8666,  5980,  9797,  3396,  6911,  9691,  7518,  2728,
#         3146,  9146,  7942,  3952,  9959,  1036,  3406,  6897,  2047,
#         1932,  2228,  2973,  8913,  8351,  7223,  4444,  5951,  8002,
#         3332,  5025,  3594,  7403,  3637,  1325,  5880,  5081,  4931,
#         9409,  6701,  2491,  9866,  5573,  9959,  1036,  3406,  6897,
#         2047,  1932,  2228,  9959,  1036,  3406,  6897,  2047,  1932,
#         2228,  9959,  1036,  3406,  6897,  2047,  1932,  2228,  6173,
#         9275,  7384,  8387,  2037, 10032,  9734,  7687,  6689,  3639,
#         6853,  7547,  6437,  9480,  9959,  1036,  3406,  6897,  2047,
#         1932,  2228,  7827,  9424,  2528,  9086,  9781,  2724,  7836,
#         9959,  1036,  3406,  6897,  2047,  1932,  2228], dtype=int64)

# %%
from collections import Counter
import operator 

c = Counter(a)
b = [l for k,l in sorted([(j,i) for i,j in c.items()], reverse=True)]
b
# Out:
# [9959,
#  6897,
#  3406,
#  2228,
#  2047,
#  1932,
#  1036,
#  7403,
#  5880,
#  5025,
#  3637,
#  3594,
#  3332,
#  1325,
#  10810,
#  10067,
#  10032,
#  9866,
#  9797,
#  9781,
#  9734,
#  9732,
#  9691,
#  9671,
#  9480,
#  9424,
#  9409,
#  9275,
#  9146,
#  9086,
#  8970,
#  8913,
#  8666,
#  8396,
#  8387,
#  8351,
#  8262,
#  8255,
#  8002,
#  7958,
#  7942,
#  7941,
#  7885,
#  7836,
#  7827,
#  7701,
#  7687,
#  7657,
#  7554,
#  7547,
#  7518,
#  7385,
#  7384,
#  7223,
#  7047,
#  6936,
#  6932,
#  6911,
#  6853,
#  6752,
#  6701,
#  6689,
#  6551,
#  6437,
#  6173,
#  6113,
#  6071,
#  5980,
#  5951,
#  5721,
#  5573,
#  5279,
#  5199,
#  5168,
#  5120,
#  5081,
#  5050,
#  4931,
#  4719,
#  4444,
#  4237,
#  4205,
#  4185,
#  3952,
#  3639,
#  3396,
#  3146,
#  2973,
#  2957,
#  2915,
#  2821,
#  2728,
#  2724,
#  2528,
#  2491,
#  2482,
#  2157,
#  2037,
#  1866,
#  1739,
#  1726,
#  1706,
#  1697,
#  1538,
#  1225,
#  1055,
#  1033,
#  1032,
#  1026,
#  946,
#  932,
#  931]

# %%
#выведем названия наиболее подходящих пользователю фильмов, отсортированные по счетчику
b = [l for k,l in sorted([(j,i) for i,j in c.items()], reverse=True)]

movies.iloc[b[1:10]]
# Out:
#       movieId                                              title  \
# 6897    63515                                  The Island (2006)
# 3406     4634                    Penn & Teller Get Killed (1989)
# 2228     2962                                 Fever Pitch (1997)
# 2047     2726                                Killing, The (1956)
# 1932     2561                                  True Crime (1999)
# 1036     1348  Nosferatu (Nosferatu, eine Symphonie des Graue...
# 7403    80094                          Last Exorcism, The (2010)
# 5880    33148                               King's Ransom (2005)
# 5025     7815                                True Stories (1986)
#
#                 genres
# 6897     Drama|Mystery
# 3406  Adventure|Comedy
# 2228    Comedy|Romance
# 2047   Crime|Film-Noir
# 1932    Crime|Thriller
# 1036            Horror
# 7403   Horror|Thriller
# 5880      Comedy|Crime
# 5025    Comedy|Musical
